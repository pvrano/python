# %%
print("hello")
# Out:
# hello

# %%
l = []
f = open("C:\\Users\\pvran\\OneDrive\\Documents\\Python Scripts\\input.txt", "r")
for line in f:
    l.append(int(line))
    
target = 2020
d= {}
for item in l:
    
    if item in d:
        print(d[item]*item)
        break
        
    else:
        d[target -item]=item
# Out:
# 713184

# %%
l = []
f = open("C:\\Users\\pvran\\OneDrive\\Documents\\Python Scripts\\input.txt", "r")
for line in f:
    l.append(int(line))
    
mujhe_mil_gaya = False
for i in range(0,len(l)):
    if mujhe_mil_gaya:
        break
    for j in range(i+1,len(l)):
        if mujhe_mil_gaya:
            break
        for k in range(j+1,len(l)):
            if l[i]+l[j]+l[k] == 2020:
                print(l[i]*l[j]*l[k])
                mujhe_mil_gaya = True
                break
# Out:
# 261244452
