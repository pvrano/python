# %%
f = open("C:\\Users\\pvran\\OneDrive\\Documents\\MyDocuments\\FinalOfferAugust2021\\New folder\\Day3.txt","r")
x = []
for line in f:
    line = line.strip()
    y = []
    for c in line:
        y.append(c)
    
    x.append(y)


for x_coor in range(0, len(x)):
   for y_coor in range(0, len(y)):
       print(x[x_coor][y_coor], end ="")
   print()
 
    
TREE = '#'    
tree_count = 0
r = 1
c = 3
while r < len(x):
    y = x[r]
    if x[r][c % len(y)] == TREE:
        tree_count += 1
        
    r += 1 # GO DOWN
    c += 3 # GO RIGHT
    
        
print(tree_count)
# Out:
# .#..#....##...#....#.....#.#...
# ........##....#..#..##....#.#..
# ......##......##.........#....#
# ...#.....#....##.......#.#....#
# .#.###.#.#..#.....##..#....#.#.
# ##.........##.....####......#..
# #...#..........#.##............
# ####............#..........#.#.
# ......#......#....##...#..##...
# #..#....#...#......#......####.
# ......#..........#.........#.#.
# ...##.......#..#.#..#..#....#..
# ..####....#.#...............##.
# ...###........#.....#..........
# #..#.##...##.#..##...##...#....
# .###........#.##..#.#.....#....
# .#.......#..##.......#......#..
# .##...........#..............#.
# ...#..#.....#...........#...#..
# .....#..............#..#.......
# .......#....#.....##...........
# .#...#.............#.....##....
# ....#.#....#...#...#..#..##.#..
# ...#..##..##...#..##........#.#
# .###..#...#.#.#.#..#...#.......
# .....##.#.##.#.#.......#..#....
# .##.#...#.....#...#....#.....#.
# .....#......###....###..##.#..#
# .....#..##....#..#.#..#.#.#....
# ...

# %%
f = open("C:\\Users\\pvran\\OneDrive\\Documents\\MyDocuments\\FinalOfferAugust2021\\New folder\\Day3.txt","r")
x = []
for line in f:
    line = line.strip()
    y = []
    for col in line:
        y.append(col)
    x.append(y)

myTuple = [(1,1),(3,1),(5,1),(7,1),(1,2)]
mul =1
for tuple in myTuple:
    TREE = '#'    
    tree_count = 0
    r = tuple[1]
    c = tuple[0]
    while r < len(x):
        y = x[r]
        if x[r][c % len(y)] == TREE:
            tree_count += 1
        
        r += tuple[1] # GO DOWN
        c += tuple[0] # GO RIGHT
    
        
    print(tree_count)
    mul = tree_count*mul
print(mul)
# Out:
# 84
# 195
# 70
# 70
# 47
# 3772314000
