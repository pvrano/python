# %%
l = []
f = open("C:\\Users\\pvran\\OneDrive\\Documents\\MyDocuments\\FinalOfferAugust2021\\New folder\\Day2.txt","r")
ValidPassword = 0
for passcode in f:
    l.append(passcode)
    splittedstring = passcode.split(":")
    #print(splittedstring)
    part1 = splittedstring[0]
    #print(part1)
    part2 = splittedstring[1].strip()
    #print(part2)
    splitPolicy = part1.split(" ")
    ranges = splitPolicy[0]
    limits = ranges.split("-")
    lowerLimit = int(limits[0])
    #print(lowerLimit)
    upperLimit = int(limits[1])
    #print(upperLimit)
    alphabet = splitPolicy[1]
    count = 0
    for i in range(0,len(part2)):
        if alphabet == part2[i]:
            count = count+1;
    #print(count)
    if lowerLimit<=count<=upperLimit:
        ValidPassword = ValidPassword + 1;
        
print("The total number of valid passwords are",ValidPassword, "out of",len(l),"entries")
# Out:
# The total number of valid passwords are 439 out of 1000 entries

# %%
l = []
f = open("C:\\Users\\pvran\\OneDrive\\Documents\\MyDocuments\\FinalOfferAugust2021\\New folder\\Day2.txt","r")
ValidPassword = 0
for passcode in f:
    l.append(passcode)
    splittedstring = passcode.split(":")
    #print(splittedstring)
    policy = splittedstring[0]
    #print(policy)
    password = splittedstring[1].strip()
    #print(password)
    splitPolicy = policy.split(" ")
    ranges = splitPolicy[0]
    limits = ranges.split("-")
    lowerLimit = int(limits[0])
    #print(lowerLimit)
    upperLimit = int(limits[1])
    #print(upperLimit)
    alphabet = splitPolicy[1]
    isPresent = False
    if password[lowerLimit-1] ==alphabet!= password[upperLimit-1]:
        isPresent = True
    elif password[lowerLimit-1] !=alphabet== password[upperLimit-1]:
        isPresent = True
    elif password[lowerLimit-1] ==alphabet== password[upperLimit-1]:
        isPresent = False
    else:
        isPresent = False
     
    if isPresent == True:
        ValidPassword = ValidPassword + 1;

print("The total number of valid passwords are",ValidPassword, "out of",len(l),"entries")
# Out:
# The total number of valid passwords are 584 out of 1000 entries
